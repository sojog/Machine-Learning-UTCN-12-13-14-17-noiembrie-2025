# %%
colectie = [ "rosu", "verde", "albastru", "negru" ]
print(type(colectie), len(colectie))
# Out:
# <class 'list'> 4

# %%
colectie = [ "rosu", "verde", "albastru", "negru" ]
for i in colectie:
    print("i=", i)
# Out:
# i= rosu
# i= verde
# i= albastru
# i= negru

# %%
colectie = ( "rosu", "verde", "albastru", "negru" )
print(type(colectie), len(colectie))
# Out:
# <class 'tuple'> 4

# %%
colectie = ( "rosu", "verde", "albastru", "negru" )
for i in colectie:
    print("i=", i)
# Out:
# i= rosu
# i= verde
# i= albastru
# i= negru

# %%
colectie = [ "rosu", "verde", "albastru", "negru" ]
colectie.append("azur")
colectie
# Out:
# ['rosu', 'verde', 'albastru', 'negru', 'azur']

# %% [markdown]
# # Tuplu este o colectie imutabila - nu pot adauga elemente in ea

# %%
colectie = ( "rosu", "verde", "albastru", "negru" )
colectie.append("azur")
colectie
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 colectie = ( "rosu", "verde", "albastru", "negru" )
# ----> 2 colectie.append("azur")
#       3 colectie
#
# AttributeError: 'tuple' object has no attribute 'append'
