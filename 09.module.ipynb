# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.cos, math.sin
# Out:
# (<function math.cos(x, /)>, <function math.sin(x, /)>)

# %%
import random

# %%
random.randint(1, 10)
# Out:
# 7

# %%
random.randint(1, 10)
# Out:
# 4

# %%
random.randint(1, 10)
# Out:
# 10

# %%
random.randint(1, 10)
# Out:
# 4

# %%
import modulul_meu

# %%
modulul_meu.functia_mea()
# Out:
# 31312
