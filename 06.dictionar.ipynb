# %%
#                0      1      2            3
colectie = [ "rosu", "verde", "albastru", "negru" ]
print(type(colectie), len(colectie))
# Out:
# <class 'list'> 4

# %%
dictionar = { "sange": "rosu", "iarba": "verde", "cer": "albastru", "ghiozdan": "negru" }
print(type(dictionar), len(dictionar))
# Out:
# <class 'dict'> 4

# %%
dictionar = { "sange": "rosu", "iarba": "verde", "cer": "albastru", "ghiozdan": "negru" }

for i in dictionar:
    print("i=", i, " valoarea: ", dictionar[i])
# Out:
# i= sange  valoarea:  rosu
# i= iarba  valoarea:  verde
# i= cer  valoarea:  albastru
# i= ghiozdan  valoarea:  negru

# %%
dictionar = { "sange": "rosu", "iarba": "verde", "cer": "albastru", "ghiozdan": "negru" }
dictionar["sange"]
# Out:
# 'rosu'

# %%
dictionar["rosu"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dictionar["rosu"]
#
# KeyError: 'rosu'

# %% [markdown]
# # Dictionarul este mutabil

# %%
dictionar["transparent"] = "apa"
dictionar
# Out:
# {'sange': 'rosu',
#  'iarba': 'verde',
#  'cer': 'albastru',
#  'ghiozdan': 'negru',
#  'transpare': 'apa',
#  'transparent': 'apa'}
